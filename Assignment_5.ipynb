# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvpatil5376-ship-it/Atharv-Patil./blob/main/Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
# Input string from user
text = input("Enter a string: ")

# Calculate and print length
print("Length of the string is:", len(text))

#2
text = input("Enter a string: ")

if len(text) < 2:
    result = ""
else:
    # First two: text[:2] | Last two: text[-2:]
    result = text[:2] + text[-2:]

print("Resulting string:", result)

#3
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

# Concatenation
combined = str1 + str2

print("The concatenated string is:", combined)
# Out:
# Enter a string: Hello
# Length of the string is: 6
# Enter a string: DYPSN
# Resulting string: DYSN
# Enter first string: Hieee
# Enter second string: Byeee
# The concatenated string is: HieeeByeee

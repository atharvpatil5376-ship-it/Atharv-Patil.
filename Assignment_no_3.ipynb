# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvpatil5376-ship-it/Atharv-Patil./blob/main/Assignment_no_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))
if a>b:
  print("a is greater than b")
elif a==b:
    print("a is equal to b")
else:
  print("a is less than b")

num=int(input("Enter a number to check if it's even or odd: "))
if num %2==0:
  print("The number is even")
else:
  print("The number is odd")

ch=input("enter the character:")
if ch.isupper():
  print("the character is uppercase")
elif ch.islower():
  print("the character is lowercase")
else:
  print("it is not an alphabet")

x=input("enter something:")
if x.isdigit():
  print("the input is a number")
elif x.isalpha():
  print("the input is character")
else:
  print("invalid input")
# Out:
# enter the value of a:12
# enter the value of b:24
# a is less than b
# Enter a number to check if it's even or odd: 3
# The number is odd
# enter the character:Hello
# it is not an alphabet
# enter something:2
# the input is a number
